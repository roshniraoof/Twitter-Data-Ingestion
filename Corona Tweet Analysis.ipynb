# %%
import os
import tweepy as tw
import pandas as pd

# %%
# !pip install --user google-colab
# Out:
# Collecting google-colab
# Requirement already satisfied: google-auth~=1.4.0 in c:\users\roshn\anaconda3\lib\site-packages (from google-colab) (1.4.2)
# Requirement already satisfied: notebook~=5.2.0 in c:\users\roshn\anaconda3\lib\site-packages (from google-colab) (5.2.2)
# Collecting portpicker~=1.2.0 (from google-colab)
# Requirement already satisfied: pandas~=0.24.0 in c:\users\roshn\anaconda3\lib\site-packages (from google-colab) (0.24.2)
# Collecting requests~=2.21.0 (from google-colab)
#   Using cached https://files.pythonhosted.org/packages/7d/e3/20f3d364d6c8e5d2353c72a67778eb189176f08e873c9900e10c0287b84b/requests-2.21.0-py2.py3-none-any.whl
# Requirement already satisfied: ipykernel~=4.6.0 in c:\users\roshn\anaconda3\lib\site-packages (from google-colab) (4.6.1)
# Requirement already satisfied: six~=1.12.0 in c:\users\roshn\anaconda3\lib\site-packages (from google-colab) (1.12.0)
# Requirement already satisfied: tornado~=4.5.0 in c:\users\roshn\anaconda3\lib\site-packages (from google-colab) (4.5.3)
# Requirement already satisfied: ipython~=5.5.0 in c:\users\roshn\anaconda3\lib\site-packages (from google-colab) (5.5.0)
# Requirement already satisfied: rsa>=3.1.4 in c:\users\roshn\anaconda3\lib\site-packages (from google-auth~=1.4.0->google-colab) (4.0)
# Requirement already satisfied: cachetools>=2.0.0 in c:\users\roshn\anaconda3\lib\site-packages (from google-auth~=1.4.0->google-colab) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\roshn\anaconda3\lib\site-packages (from google-auth~=1.4.0->google-colab) (0.2.8)
# Requirement already satisfied: nbconvert in c:\users\roshn\anaconda3\lib\site-packages (from notebook~=5.2.0->google-colab) (5.6.0)
# Requirement already satisfied: jupyter-client in c:\users\roshn\anaconda3\lib\site-packages (from notebook~=5.2.0->google-colab) (5.3.3)
# Requirement already satisfied: ipython-genutils in c:\users\roshn\anaconda3\lib\site-packages (from notebook~=5.2.0->google-colab) (0.2.0)
# Requirement already satisfied: jinja2 in c:\users\roshn\anaconda3\lib\site-packages (from notebook~=5.2.0->google-colab) (2.10.3)
# Requirement already satisfied: traitlets>=4.2.1 in c:\users\roshn\anaconda3\lib\site-packages (from notebook~=5.2.0->google-colab) (4.3.3)
# Requirement already satisfied: jupyter-core in c:\users\roshn\anaconda3\lib\site-packages (from notebook~=5.2.0->google-colab) (4.5.0)
# Requirement already satisfied: nbformat in c:\users\roshn\anaconda3\lib\site-packages (from notebook~=5.2.0->google-colab) (4.4.0)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\roshn\anaconda3\lib\site-packages (from pandas~=0.24.0->google-colab) (2.8.0)
# Requirement already satisfied: pytz>=2011k in c:\users\roshn\anaconda3\lib\site-packages (from pandas~=0.24.0->google-colab) (2019.3)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\roshn\anaconda3\lib\site-packages (from pandas~=0.24.0->google-colab) (1.16.5)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\roshn\anaconda3\lib\site-packages (from requests~=2.21.0->google-colab) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\roshn\anaconda3\lib\site-packages (from requests~=2.21.0->google-colab) (2019.9.11)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\roshn\anaconda3\lib\site-packages (from requests~=2.21.0->google-colab) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\roshn\anaconda3\lib\site-packages (from requests~=2.21.0->google-colab) (2.8)
# Requirement already satisfied: decorator in c:\users\roshn\anaconda3\lib\site-packages (from ipython~=5.5.0->google-colab) (4.4.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\roshn\anaconda3\lib\site-packages (from ipython~=5.5.0->google-colab) (41.4.0)
# Requirement already satisfied: pickleshare in c:\users\roshn\anaconda3\lib\site-packages (from ipython~=5.5.0->google-colab) (0.7.5)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\roshn\anaconda3\lib\site-packages (from ipython~=5.5.0->google-colab) (0.4.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in c:\users\roshn\anaconda3\lib\site-packages (from ipython~=5.5.0->google-colab) (1.0.18)
# Requirement already satisfied: pygments in c:\users\roshn\anaconda3\lib\site-packages (from ipython~=5.5.0->google-colab) (2.4.2)
# Requirement already satisfied: simplegeneric>0.8 in c:\users\roshn\anaconda3\lib\site-packages (from ipython~=5.5.0->google-colab) (0.8.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\roshn\anaconda3\lib\site-packages (from rsa>=3.1.4->google-auth~=1.4.0->google-colab) (0.4.8)
# Requirement already satisfied: defusedxml in c:\users\roshn\anaconda3\lib\site-packages (from nbconvert->notebook~=5.2.0->google-colab) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\roshn\anaconda3\lib\site-packages (from nbconvert->notebook~=5.2.0->google-colab) (0.3)
# Requirement already satisfied: bleach in c:\users\roshn\anaconda3\lib\site-packages (from nbconvert->notebook~=5.2.0->google-colab) (3.1.0)
# Requirement already satisfied: testpath in c:\users\roshn\anaconda3\lib\site-packages (from nbconvert->notebook~=5.2.0->google-colab) (0.4.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\roshn\anaconda3\lib\site-packages (from nbconvert->notebook~=5.2.0->google-colab) (1.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\roshn\anaconda3\lib\site-packages (from nbconvert->notebook~=5.2.0->google-colab) (0.8.4)
# Requirement already satisfied: pyzmq>=13 in c:\users\roshn\anaconda3\lib\site-packages (from jupyter-client->notebook~=5.2.0->google-colab) (18.1.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\roshn\anaconda3\lib\site-packages (from jupyter-client->notebook~=5.2.0->google-colab) (223)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\roshn\anaconda3\lib\site-packages (from jinja2->notebook~=5.2.0->google-colab) (1.1.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\roshn\anaconda3\lib\site-packages (from nbformat->notebook~=5.2.0->google-colab) (3.0.2)
# Requirement already satisfied: wcwidth in c:\users\roshn\anaconda3\lib\site-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython~=5.5.0->google-colab) (0.1.7)
# Requirement already satisfied: webencodings in c:\users\roshn\anaconda3\lib\site-packages (from bleach->nbconvert->notebook~=5.2.0->google-colab) (0.5.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\roshn\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook~=5.2.0->google-colab) (0.15.4)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\roshn\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook~=5.2.0->google-colab) (19.2.0)
# Installing collected packages: portpicker, requests, google-colab
# Successfully installed google-colab-1.0.0 portpicker-1.2.0 requests-2.21.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-51-d5df0069828e> in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
import configparser
config = configparser.RawConfigParser()
config.read('/content/drive/My Drive/twitter.properties')
print(config.sections());

# %%
# !ls '/content/drive/
# Out:
# ls: cannot access '/content/drive/': No such file or directory

# %%
consumer_key= 'yAFwOdiTwkbeuNF6FYyauTURs'
consumer_secret= 'vL3HeWIdruYhTrnvsLIXuvRDWBD0iaKBBZgt7hWKEzPbCOtfuF'
access_token= '2241918396-Q9PQ6lm4xkWoHyOzzEZXgfGOTiy51cOXmXI03W5'
access_token_secret= 'c8jyFe4VhTICSwChMInAOundrJuFIi762wmVm7CtP9IoG'
googleapikey= 'AIzaSyDvovKj8_KZp2px99pItAZez_xvJMs_3gg'

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
search_words = "#coronavirus"
date_since = "2020-03-10"

# %%
tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(100)
tweet_details = [[tweet.geo, tweet.text,tweet.user.screen_name, tweet.user.location]  for tweet in tweets]

# %%
tweet_df = pd.DataFrame(data=tweet_details, columns =['geo','text', 'user', 'location'])

# %%
pd.set_option('max_colwidth',800)
tweet_df.head(20)
# Out:
#      geo  \
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# 5   None
# 6   None
# 7   None
# 8   None
# 9   None
# 10  None
# 11  None
# 12  None
# 13  None
# 14  None
# 15  None
# 16  None
# 17  None
# 18  None
# 19  None
#
#                                                                                                                                                  text  \
# 0        RT @eoghanmcdermo: Obvious but super important point from Chief Medical Officer Tony Houlahan. Most young people will be fine if they contr…
# 1   RT @AK91859543: Ireland: 43 Cases of Corona \n‘Close all schools’ \nScotland: 60 cases of Corona\n‘Close all schools’\nEngland: 500+ cases\n‘Hmm…
# 2                                                     Support #Taiwan into #WHO\nhttps://t.co/nEstpKbK7B    \n#WuhanCoronavirus #COVID19 #coronavirus
# 3                                                            RT @JamesHillTV: The #CoronaVirus out here canceling everything but these student loans.
# 4      RT @markcmarino: We all just took our classes online.  Before we move on, could we just take a minute?\n\nHere's something a wrote about it..…
# 5       Main Street is barren\neveryone's staying inside\nfearing the virus\n#haikuchallenge (street) #haiku #senryu #poetry… https://t.co/NcwpZVX3Ow
# 6    RT @feelthepress: BREAKING \n\nItalian medical chief, Roberto Stella, 67, dies from #coronavirus due to respiratory failure\n\n#COVID19  https:…
# 7        What’s the line on @realDonaldTrump @POTUS has #coronavirus after repeatedly meeting with people that either have t… https://t.co/NFXiDwXRIi
# 8      RT @dw_sports: Hannover players have been put in home-bound quarantine for 14 days.\n\nTwo of their players, Timo Hübers and Jannes Horn, hav…
# 9        Amid all the #coronavirus media coverage, here's something a bit more specific to the #jobseeker and #jobsearch wor… https://t.co/m0rwb1QWOx
# 10             RT @POPSUGARUK: .@ChiaraFerragni has had to triple the fundraising target to €4 Million! 👏 #Coronavirus #Italy https://t.co/OJzYkMim4Z
# 11       Hope out @POTUS @realDonaldTrump doesn’t get \nVirus due to Brazilian visitor from Govt at @MaralagoFL that brought… https://t.co/UpVKRYNECi
# 12                                   RT @WarsontheBrink: BREAKING:\n\n111 new cases of #coronavirus in Netherlands. Total reaches 614 confirmed cases
# 13     RT @NivElis: Just a reminder, health experts say one thing you can do is *get your flu shot.*\n\nWhy? Because the fewer cases of flu going ar…
# 14       RT @LindseyGrahamSC: President @realDonaldTrump laid out a very good roadmap to achieve economic stability and contain the spread of #coron…
# 15       RT @ANI: Maharashtra Health Minister Rajesh Tope on IPL: Cabinet discussed and we are of the view that big gatherings should be avoided. We…
# 16                                                   RT @deAdder: Cartoon on #coronavirus #TrumpVirus #Trump2020 #Trumpspeech https://t.co/Bo6WIxz3KJ
# 17      RT @Nectar_Gan: This is beyond shocking\n\nChina shut down the lab that published the world’s first genome sequence of the #coronavirus last…
# 18       #Breaking: #COVID-19 infected Aussie woman stranded in #Aspen apartment runs out of #chardonnay but luckily the Gro… https://t.co/Akf35IDhN0
# 19     The #coronavirus has given @realDonaldTrump all the cover he needs to double down on his #AmericaFirst agenda.\n\nThe… https://t.co/NwjD5FXduk
#
#                user                        location
# 0      CareerGirl32           North West Lancashire
# 1   SophieOverfield                   York, England
# 2         tszyu0824                  United Kingdom
# 3       jalena_lena
# 4      ermes_marana                       Sophronia
# 5      cleekmaker00  The Mile High City. Denver, CO
# 6      jerzeygirl99                            Jerz
# 7   joshuasparker06           ParkerDobbs Sanctuary
# 8       jhoe_banton                        With God
# 9   RecruiterFinder                 Long Island, NY
# 10      ilothebardo
# 11   AlwaystrumpOrg              Manassas, Virginia
# 12        AAhmed991                  کراچی, پاکستان
# 13      scottwongDC                Washington, D.C.
# 14        jgraham55
# 15     Dhirajkrshaw            West Bengal, India🇮🇳
# 16           21LegM
# 17     AdamForTrump                 Los Angeles, CA
# 18    artistinaspen                       Aspen, CO
# 19   MichaelOHogan1

# %%
import re
def clean_tweets(text):
    text =re.sub("RT @[\w]*:", "", text)
    text =re.sub("@[\w]*", "", text)
    text =re.sub("https?://[A-Za-z0-9./]*", "", text)
    text =re.sub("\n", "", text)
    return text

# %%
tweet_df['text']=tweet_df['text'].apply(lambda x: clean_tweets(x))

# %%
tweet_df.head(20)
# Out:
#      geo  \
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# 5   None
# 6   None
# 7   None
# 8   None
# 9   None
# 10  None
# 11  None
# 12  None
# 13  None
# 14  None
# 15  None
# 16  None
# 17  None
# 18  None
# 19  None
#
#                                                                                                                                     text  \
# 0              Obvious but super important point from Chief Medical Officer Tony Houlahan. Most young people will be fine if they contr…
# 1                Ireland: 43 Cases of Corona ‘Close all schools’ Scotland: 60 cases of Corona‘Close all schools’England: 500+ cases‘Hmm…
# 2                                                                   Support #Taiwan into #WHO    #WuhanCoronavirus #COVID19 #coronavirus
# 3                                                                The #CoronaVirus out here canceling everything but these student loans.
# 4              We all just took our classes online.  Before we move on, could we just take a minute?Here's something a wrote about it..…
# 5                       Main Street is barreneveryone's staying insidefearing the virus#haikuchallenge (street) #haiku #senryu #poetry…
# 6                 BREAKING Italian medical chief, Roberto Stella, 67, dies from #coronavirus due to respiratory failure#COVID19  https:…
# 7                                        What’s the line on   has #coronavirus after repeatedly meeting with people that either have t…
# 8            Hannover players have been put in home-bound quarantine for 14 days.Two of their players, Timo Hübers and Jannes Horn, hav…
# 9                  Amid all the #coronavirus media coverage, here's something a bit more specific to the #jobseeker and #jobsearch wor…
# 10                                                      . has had to triple the fundraising target to €4 Million! 👏 #Coronavirus #Italy
# 11                                                    Hope out   doesn’t get Virus due to Brazilian visitor from Govt at  that brought…
# 12                                              BREAKING:111 new cases of #coronavirus in Netherlands. Total reaches 614 confirmed cases
# 13         Just a reminder, health experts say one thing you can do is *get your flu shot.*Why? Because the fewer cases of flu going ar…
# 14                               President  laid out a very good roadmap to achieve economic stability and contain the spread of #coron…
# 15   Maharashtra Health Minister Rajesh Tope on IPL: Cabinet discussed and we are of the view that big gatherings should be avoided. We…
# 16                                                                          Cartoon on #coronavirus #TrumpVirus #Trump2020 #Trumpspeech
# 17             This is beyond shockingChina shut down the lab that published the world’s first genome sequence of the #coronavirus last…
# 18                 #Breaking: #COVID-19 infected Aussie woman stranded in #Aspen apartment runs out of #chardonnay but luckily the Gro…
# 19                                   The #coronavirus has given  all the cover he needs to double down on his #AmericaFirst agenda.The…
#
#                user                        location
# 0      CareerGirl32           North West Lancashire
# 1   SophieOverfield                   York, England
# 2         tszyu0824                  United Kingdom
# 3       jalena_lena
# 4      ermes_marana                       Sophronia
# 5      cleekmaker00  The Mile High City. Denver, CO
# 6      jerzeygirl99                            Jerz
# 7   joshuasparker06           ParkerDobbs Sanctuary
# 8       jhoe_banton                        With God
# 9   RecruiterFinder                 Long Island, NY
# 10      ilothebardo
# 11   AlwaystrumpOrg              Manassas, Virginia
# 12        AAhmed991                  کراچی, پاکستان
# 13      scottwongDC                Washington, D.C.
# 14        jgraham55
# 15     Dhirajkrshaw            West Bengal, India🇮🇳
# 16           21LegM
# 17     AdamForTrump                 Los Angeles, CA
# 18    artistinaspen                       Aspen, CO
# 19   MichaelOHogan1

# %%
tweet_df.to_csv('tweets_csv')

# %%
import spacy

nlp =spacy.load('en_core_web_sm')

# %%
tweet_df['text'].apply(lambda x: [print("\tText: {} , Entity : {} ".format(ent.text,ent.label_)) if (not ent.text.startswith('#')) else "" for ent in nlp(x).ents])
# Out:
# 	Text: Tony Houlahan , Entity : PERSON
# 	Text: Ireland , Entity : GPE
# 	Text: 43 , Entity : CARDINAL
# 	Text: Scotland , Entity : GPE
# 	Text: 60 , Entity : CARDINAL
# 	Text: 500 , Entity : CARDINAL
# 	Text: Taiwan , Entity : GPE
# 	Text: WuhanCoronavirus , Entity : ORG
# 	Text: CoronaVirus , Entity : PERSON
# 	Text: Italian , Entity : NORP
# 	Text: Roberto Stella , Entity : PERSON
# 	Text: 67 , Entity : DATE
# 	Text: coronavirus , Entity : PERSON
# 	Text: Hannover , Entity : GPE
# 	Text: 14 days , Entity : DATE
# 	Text: Two , Entity : CARDINAL
# 	Text: Timo Hübers , Entity : PERSON
# 	Text: Jannes Horn , Entity : PERSON
# 	Text: jobsearch , Entity : PERSON
# 	Text: €4 Million , Entity : MONEY
# 	Text: Virus , Entity : ORG
# 	Text: Brazilian , Entity : NORP
# 	Text: Govt , Entity : ORG
# 	Text: Netherlands , Entity : GPE
# 	Text: 614 , Entity : CARDINAL
# 	Text: one , Entity : CARDINAL
# 	Text: Maharashtra Health , Entity : ORG
# 	Text: Rajesh Tope , Entity : PERSON
# 	Text: IPL , Entity : ORG
# 	Text: Cartoon , Entity : PERSON
# 	Text: shockingChina shut , Entity : PERSON
# 	Text: first , Entity : ORDINAL
# 	Text: Breaking , Entity : PERSON
# 	Text: Aussie , Entity : ORG
# 	Text: Aspen , Entity : PERSON
# 	Text: AmericaFirst , Entity : PERSON
# 	Text: Tom Hanks' , Entity : PERSON
# 	Text: Chet , Entity : PERSON
# 	Text: CoronaVirus , Entity : PERSON
# 	Text: Cheltenham , Entity : PERSON
# 	Text: nCoVPandemic , Entity : MONEY
# 	Text: More than 6 , Entity : CARDINAL
# 	Text: 331 million , Entity : CARDINAL
# 	Text: the 1 million #coronavirus , Entity : MONEY
# 	Text: The next few months , Entity : DATE
# 	Text: American , Entity : NORP
# 	Text: Coronavirus , Entity : ORG
# 	Text: Peter Rabbit 2 , Entity : PERSON
# 	Text: Coronavirus , Entity : PERSON
# 	Text: Europe , Entity : LOC
# 	Text: CDC , Entity : ORG
# 	Text: CDC , Entity : ORG
# 	Text: Jay Butler , Entity : PERSON
# 	Text: about #coron , Entity : MONEY
# 	Text: Robert O'Brien , Entity : PERSON
# 	Text: China , Entity : GPE
# 	Text: Cost the World' , Entity : WORK_OF_ART
# 	Text: O’Brien , Entity : ORG
# 	Text: India , Entity : GPE
# 	Text: &gt , Entity : ORG
# 	Text: Fantastic , Entity : ORG
# 	Text: 1918-20 , Entity : DATE
# 	Text: Spanish , Entity : NORP
# 	Text: Trump , Entity : PERSON
# 	Text: Oval Office , Entity : ORG
# 	Text: Coronavirus , Entity : PERSON
# 	Text: MAGA , Entity : ORG
# 	Text: Trump , Entity : PRODUCT
# 	Text: about #coronavirus , Entity : MONEY
# 	Text: about #Coronavirus , Entity : MONEY
# 	Text: coronavirus , Entity : PERSON
# 	Text: Coronavirus , Entity : PERSON
# 	Text: NCAA , Entity : ORG
# 	Text: First , Entity : ORDINAL
# 	Text: WTH , Entity : ORG
# 	Text: Pelosi , Entity : ORG
# 	Text: March 9th , Entity : DATE
# 	Text: Democrats , Entity : NORP
# 	Text: FakeNews , Entity : PERSON
# 	Text: U.S. , Entity : GPE
# 	Text: Coronavirus , Entity : PERSON
# 	Text: McConnell , Entity : ORG
# 	Text: Senate , Entity : ORG
# 	Text: House , Entity : ORG
# 	Text: Senate , Entity : ORG
# 	Text: Tonight , Entity : TIME
# 	Text: Philippine , Entity : NORP
# 	Text: Duterte &amp , Entity : ORG
# 	Text: Singapore , Entity : GPE
# 	Text: Lee Hsien Loong , Entity : PERSON
# 	Text: UK , Entity : GPE
# 	Text: American , Entity : NORP
# 	Text: McConnell , Entity : ORG
# 	Text: Senate , Entity : ORG
# 	Text: House , Entity : ORG
# 	Text: Senate , Entity : ORG
# 	Text: Tonight , Entity : TIME
# 	Text: Coronavirus , Entity : PERSON
# 	Text: U.S. , Entity : GPE
# 	Text: NehaDhupia , Entity : PERSON
# 	Text: Coronavirus , Entity : PERSON
# 	Text: India , Entity : GPE
# 	Text: coronavirus , Entity : PERSON
# 	Text: Coronavirus , Entity : PERSON
# 	Text: UAE , Entity : ORG
# 	Text: 85 , Entity : CARDINAL
# 	Text: today , Entity : DATE
# 	Text: 11 , Entity : CARDINAL
# 	Text: this weekend , Entity : DATE
# 	Text: Mexican , Entity : NORP
# 	Text: Italian , Entity : NORP
# 	Text: Roberto Stella , Entity : PERSON
# 	Text: 67 , Entity : DATE
# 	Text: coronavirus , Entity : PERSON
# 	Text: House , Entity : ORG
# 	Text: Dems , Entity : NORP
# 	Text: billion dollar # , Entity : MONEY
# 	Text: 😒 , Entity : PERSON
# 	Text: one , Entity : CARDINAL
# 	Text: Canada , Entity : GPE
# 	Text: SocialDistancing , Entity : PERSON
# 	Text: FlatteningTheCurve , Entity : PERSON
# 	Text: SEC , Entity : ORG
# 	Text: Bridgestone Arena , Entity : PERSON
# 	Text: Yesterday , Entity : DATE
# 	Text: TrumpAdmin , Entity : PERSON
# 	Text: Trump , Entity : PRODUCT
# 	Text: CoronavirusOutbreak , Entity : PRODUCT
# 	Text: China , Entity : GPE
# 	Text: Wales , Entity : ORG
# 	Text: 'A Quiet Place 2' , Entity : WORK_OF_ART
# 	Text: CoronaVirus , Entity : ORG
# 	Text: Today , Entity : DATE
# 	Text: CobraMeeting , Entity : PERSON
# 	Text: Hundreds , Entity : CARDINAL
# 	Text: Thai , Entity : NORP
# 	Text: Karachi , Entity : PERSON
# 	Text: Sindh , Entity : PERSON
# 	Text: day &amp , Entity : DATE
# 	Text: Brazilian , Entity : NORP
# 	Text: Trump , Entity : PERSON
# 	Text: Pence , Entity : PERSON
# 	Text: last weekend , Entity : DATE
# 	Text: House , Entity : ORG
# 	Text: American , Entity : NORP
# 	Text: U.S. , Entity : GPE
# 	Text: MyChart , Entity : PERSON
# 	Text: one , Entity : CARDINAL
# 	Text: US , Entity : GPE
# 	Text: Excellence Ireland , Entity : GPE
# 	Text: Trump , Entity : PERSON
# 	Text: Europe , Entity : LOC
# 	Text: Financial Asst , Entity : ORG
# 	Text: Coronavirus , Entity : PERSON
# 	Text: Nancy , Entity : PERSON
# 	Text: 14 day , Entity : DATE
# 	Text: TIP , Entity : ORG
# 	Text: aloe vera , Entity : ORG
# 	Text: 1 cup , Entity : QUANTITY
# 	Text: Japan , Entity : GPE
# 	Text: 600 #coronavirus , Entity : MONEY
# 	Text: Estonia &amp , Entity : ORG
# 	Text: Hungary , Entity : GPE
# 	Text: less than 20 , Entity : CARDINAL
# 	Text: Estonia &amp , Entity : ORG
# 	Text: KC Live , Entity : FAC
# 	Text: today , Entity : DATE
# 	Text: 2 , Entity : CARDINAL
# 	Text: Robert Redfield , Entity : PERSON
# 	Text: Anthony Fauci , Entity : PERSON
# 	Text: Coronavirus , Entity : PERSON

# %%
tweet_df['entities']=tweet_df['text'].apply(lambda x: [(ent.text,ent.label_) if (not ent.text.startswith('#')) else "" for ent in nlp(x).ents])

# %%
tweet_df.head(20)
# Out:
#      geo  \
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# 5   None
# 6   None
# 7   None
# 8   None
# 9   None
# 10  None
# 11  None
# 12  None
# 13  None
# 14  None
# 15  None
# 16  None
# 17  None
# 18  None
# 19  None
#
#                                                                                                                                     text  \
# 0              Obvious but super important point from Chief Medical Officer Tony Houlahan. Most young people will be fine if they contr…
# 1                Ireland: 43 Cases of Corona ‘Close all schools’ Scotland: 60 cases of Corona‘Close all schools’England: 500+ cases‘Hmm…
# 2                                                                   Support #Taiwan into #WHO    #WuhanCoronavirus #COVID19 #coronavirus
# 3                                                                The #CoronaVirus out here canceling everything but these student loans.
# 4              We all just took our classes online.  Before we move on, could we just take a minute?Here's something a wrote about it..…
# 5                       Main Street is barreneveryone's staying insidefearing the virus#haikuchallenge (street) #haiku #senryu #poetry…
# 6                 BREAKING Italian medical chief, Roberto Stella, 67, dies from #coronavirus due to respiratory failure#COVID19  https:…
# 7                                        What’s the line on   has #coronavirus after repeatedly meeting with people that either have t…
# 8            Hannover players have been put in home-bound quarantine for 14 days.Two of their players, Timo Hübers and Jannes Horn, hav…
# 9                  Amid all the #coronavirus media coverage, here's something a bit more specific to the #jobseeker and #jobsearch wor…
# 10                                                      . has had to triple the fundraising target to €4 Million! 👏 #Coronavirus #Italy
# 11                                                    Hope out   doesn’t get Virus due to Brazilian visitor from Govt at  that brought…
# 12                                              BREAKING:111 new cases of #coronavirus in Netherlands. Total reaches 614 confirmed cases
# 13         Just a reminder, health experts say one thing you can do is *get your flu shot.*Why? Because the fewer cases of flu going ar…
# 14                               President  laid out a very good roadmap to achieve economic stability and contain the spread of #coron…
# 15   Maharashtra Health Minister Rajesh Tope on IPL: Cabinet discussed and we are of the view that big gatherings should be avoided. We…
# 16                                                                          Cartoon on #coronavirus #TrumpVirus #Trump2020 #Trumpspeech
# 17             This is beyond shockingChina shut down the lab that published the world’s first genome sequence of the #coronavirus last…
# 18                 #Breaking: #COVID-19 infected Aussie woman stranded in #Aspen apartment runs out of #chardonnay but luckily the Gro…
# 19                                   The #coronavirus has given  all the cover he needs to double down on his #AmericaFirst agenda.The…
#
#                user                        location  \
# 0      CareerGirl32           North West Lancashire
# 1   SophieOverfield                   York, England
# 2         tszyu0824                  United Kingdom
# 3       jalena_lena
# 4      ermes_marana                       Sophronia
# 5      cleekmaker00  The Mile High City. Denver, CO
# 6      jerzeygirl99                            Jerz
# 7   joshuasparker06           ParkerDobbs Sanctuary
# 8       jhoe_banton                        With God
# 9   RecruiterFinder                 Long Island, NY
# 10      ilothebardo
# 11   AlwaystrumpOrg              Manassas, Virginia
# 12        AAhmed991                  کراچی, پاکستان
# 13      scottwongDC                Washington, D.C.
# 14        jgraham55
# 15     Dhirajkrshaw            West Bengal, India🇮🇳
# 16           21LegM
# 17     AdamForTrump                 Los Angeles, CA
# 18    artistinaspen                       Aspen, CO
# 19   MichaelOHogan1
#
#                                                                                              entities
# 0                                                                           [(Tony Houlahan, PERSON)]
# 1                  [(Ireland, GPE), (43, CARDINAL), (Scotland, GPE), (60, CARDINAL), (500, CARDINAL)]
# 2                                                            [(Taiwan, GPE), (WuhanCoronavirus, ORG)]
# 3                                                                             [(CoronaVirus, PERSON)]
# 4                                                                                                  []
# 5                                                                                                  []
# 6                      [(Italian, NORP), (Roberto Stella, PERSON), (67, DATE), (coronavirus, PERSON)]
# 7                                                                                                  []
# 8   [(Hannover, GPE), (14 days, DATE), (Two, CARDINAL), (Timo Hübers, PERSON), (Jannes Horn, PERSON)]
# 9                                                                           [, , (jobsearch, PERSON)]
# 10                                                                              [(€4 Million, MONEY)]
# 11                                                     [(Virus, ORG), (Brazilian, NORP), (Govt, ORG)]
# 12                                                              [(Netherlands, GPE), (614, CARDINAL)]
# 13                                                                                  [(one, CARDINAL)]
# 14                                                                                                 []
# 15                                     [(Maharashtra Health, ORG), (Rajesh Tope, PERSON), (IPL, ORG)]
# 16                                                                              [(Cartoon, PERSON), ]
# 17                                                   [(shockingChina shut, PERSON), (first, ORDINAL)]
# 18                                             [(Breaking, PERSON), , (Aussie, ORG), (Aspen, PERSON)]
# 19                                                                           [(AmericaFirst, PERSON)]

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\roshn\AppData\Roaming\nltk_data...
# True

# %%
sid = SentimentIntensityAnalyzer()

# %%
tweet_df['sentiment']=tweet_df['text'].apply(lambda x: sid.polarity_scores(x))

# %%
tweet_df.head(10)
# Out:
#     geo  \
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
# 5  None
# 6  None
# 7  None
# 8  None
# 9  None
#
#                                                                                                                            text  \
# 0     Obvious but super important point from Chief Medical Officer Tony Houlahan. Most young people will be fine if they contr…
# 1       Ireland: 43 Cases of Corona ‘Close all schools’ Scotland: 60 cases of Corona‘Close all schools’England: 500+ cases‘Hmm…
# 2                                                          Support #Taiwan into #WHO    #WuhanCoronavirus #COVID19 #coronavirus
# 3                                                       The #CoronaVirus out here canceling everything but these student loans.
# 4     We all just took our classes online.  Before we move on, could we just take a minute?Here's something a wrote about it..…
# 5              Main Street is barreneveryone's staying insidefearing the virus#haikuchallenge (street) #haiku #senryu #poetry…
# 6        BREAKING Italian medical chief, Roberto Stella, 67, dies from #coronavirus due to respiratory failure#COVID19  https:…
# 7                               What’s the line on   has #coronavirus after repeatedly meeting with people that either have t…
# 8   Hannover players have been put in home-bound quarantine for 14 days.Two of their players, Timo Hübers and Jannes Horn, hav…
# 9         Amid all the #coronavirus media coverage, here's something a bit more specific to the #jobseeker and #jobsearch wor…
#
#               user                        location  \
# 0     CareerGirl32           North West Lancashire
# 1  SophieOverfield                   York, England
# 2        tszyu0824                  United Kingdom
# 3      jalena_lena
# 4     ermes_marana                       Sophronia
# 5     cleekmaker00  The Mile High City. Denver, CO
# 6     jerzeygirl99                            Jerz
# 7  joshuasparker06           ParkerDobbs Sanctuary
# 8      jhoe_banton                        With God
# 9  RecruiterFinder                 Long Island, NY
#
#                                                                                             entities  \
# 0                                                                          [(Tony Houlahan, PERSON)]
# 1                 [(Ireland, GPE), (43, CARDINAL), (Scotland, GPE), (60, CARDINAL), (500, CARDINAL)]
# 2                                                           [(Taiwan, GPE), (WuhanCoronavirus, ORG)]
# 3                                                                            [(CoronaVirus, PERSON)]
# 4                                                                                                 []
# 5                                                                                                 []
# 6                     [(Italian, NORP), (Roberto Stella, PERSON), (67, DATE), (coronavirus, PERSON)]
# 7                                                                                                 []
# 8  [(Hannover, GPE), (14 days, DATE), (Two, CARDINAL), (Timo Hübers, PERSON), (Jannes Horn, PERSON)]
# 9                                                                          [, , (jobsearch, PERSON)]
#
#                                                       sentiment
# 0  {'neg': 0.0, 'neu': 0.636, 'pos': 0.364, 'compound': 0.8674}
# 1         {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 2    {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.4019}
# 3         {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 4         {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 5         {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 6         {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 7         {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 8         {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 9         {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
import googlemaps
# Out:
# []

# %%
gmaps = googlemaps.Client(key='AIzaSyDvovKj8_KZp2px99pItAZez_xvJMs_3gg')
geocode_result = gmaps.geocode(tweet_df['location'][3])
print(geocode_result)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-54-900de0b430f4> in <module>
#       1 gmaps = googlemaps.Client(key='AIzaSyDvovKj8_KZp2px99pItAZez_xvJMs_3gg')
# ----> 2 geocode_result = gmaps.geocode(tweet_df['location'][3])
#       3 print(geocode_result)
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in wrapper(*args, **kwargs)
#     407     def wrapper(*args, **kwargs):
#     408         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 409         result = func(*args, **kwargs)
#     410         try:
#     411             del args[0]._extra_params
#
# ~\Anaconda3\lib\site-packages\googlemaps\geocoding.py in geocode(client, address, components, bounds, region, language)
#      66         params["language"] = language
#      67
# ---> 68     return client._request("/maps/api/geocode/json", params).get("results", [])
#      69
#      70
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     302                 result = extract_body(response)
#     303             else:
# --> 304                 result = self._get_body(response)
#     305             self.sent_times.append(time.time())
#     306             return result
#
# ~\Anaconda3\lib\site-packages\googlemaps\client.py in _get_body(self, response)
#     319     def _get_body(self, response):
#     320         if response.status_code != 200:
# --> 321             raise googlemaps.exceptions.HTTPError(response.status_code)
#     322
#     323         body = response.json()
#
# HTTPError: HTTP Error: 400
